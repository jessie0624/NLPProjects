# %%
ls
# Out:
# book_cover.zip  dev_clean.csv  stopwords.txt  test_clean.csv  train_clean.csv

# %%
open("stopwords.txt", encoding="utf-8").readlines()
# Out:
# ['\ufeff¡\n',
#  '¦\n',
#  '«\n',
#  '\xad\n',
#  '¯\n',
#  '居于\n',
#  '以阿\n',
#  '请以\n',
#  '可别\n',
#  '得以\n',
#  '商与\n',
#  '说他\n',
#  '因为阿\n',
#  '就是阿\n',
#  '´\n',
#  '·\n',
#  '为您\n',
#  '出得\n',
#  '还有\n',
#  '就是\n',
#  '在产\n',
#  '也许就\n',
#  '¸\n',
#  '文中\n',
#  '在中\n',
#  '才有\n',
#  '而非\n',
#  '\n',
#  '就不能\n',
#  '为什么阿\n',
#  '是让\n',
#  '»\n',
#  '¿\n',
#  '×××\n',
#  '\\u3000\n',
#  '×\n',
#  '.h\n',
#  'tml\n',
#  '.h_tml\n',
#  '\\n\n',
#  '_\n',
#  '很多人\n',
#  '\n',
#  'ˇ\n',
#  'ˉ\n',
#  'ˊ\n',
#  '并与\n',
#  'ˋ\n',
#  '˜\n',
#  'Δ\n',
#  'Ψ\n',
#  'γ\n',
#  'μ\n',
#  'φ．\n',
#  'φ\n',
#  'В\n',
#  '‐\n',
#  '–\n',
#  '———\n',
#  '——\n',
#  '—\u3000\n',
#  '—\n',
#  '―\n',
#  '‖\n',
#  '‘\n',
#  '’‘\n',
#  '’\n',
#  '“\n',
#  '”，\n',
#  '”\n',
#  '•\n',
#  '………………………………………………\n',
#  '……………………………………………\n',
#  '……\n',
#  '…\n',
#  '′∈\n',
#  '′｜\n',
#  '′\n',
#  '‹\n',
#  '›\n',
#  '※\n',
#  '℃\n',
#  'Ⅲ\n',
#  '↑\n',
#  '→\n',
#  '∈［\n',
#  '∕\n',
#  '∥\n',
#  '∧\n',
# ...

# %%
ls
# Out:
# sh: 0: getcwd() failed: No such file or directory
