# %%
ls
# Out:
# data/                                           logs/   Untitled.ipynb
# __init__.py                                     model/
# LightGBM_feature_engineering_grid(To_Do).ipynb  src/

# %%
root_path = "/home/jie/Documents/JIE_NLP/NLPProjects/textClassification"

# %%
import pandas as pd

data = pd.concat([pd.read_csv(root_path + '/data/train_clean.csv', sep='\t'),
                  pd.read_csv(root_path + '/data/dev_clean.csv', sep='\t'),
                  pd.read_csv(root_path + '/data/test_clean.csv', sep='\t')])
# Out:
# /root/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /root/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data
# Out:
#                                                     text    label  category_id
# 0      杏林 芳菲 广东 中医药 曹磊 编著 的 杏林 芳菲 广东 中医药 注重 文化 内涵 的 挖...       文化            6
# 1      额吉 的 白云 优秀 蒙古文 文学作品 翻译 出版 工程 第五辑 散文 卷 散文集 额吉 的...       文学            0
# 2      叶赛宁 抒情诗 选 本书 收入 叶赛宁 的 206 首 抒情诗 , 多为 名篇 佳作 叶赛宁...       文学            0
# 3      待 我 长发 及 腰 . 娶 我 可好 走过 唐诗 , 路过 宋词 , 相约 在 江南 的 ...       文学            0
# 4      公司债务 融资 及其 相关 金融 系统 本书 结合 经济 生活 热点 和 前沿 问题 , 对...       管理            1
# 5      朱光潜 经典 作品集 : 谈 文学 增订本 本书 是 著名 美学家 、 文艺 理论家 、 教...       文学            0
# 6      福利 治理 视角 下 城市 困境 儿童 的 福利 提供 基于 南京市 FH 街道 的 个案 ...     社会科学           13
# 7      中南 博集 天卷 文化传媒 有限公司 湘行 散记 精装 沈从文 沈从文 是 现代文学 目前 ...       文学            0
# 8      钢铁 是 怎样 炼成 的 插图 珍藏版 奥斯特洛夫斯基 的 钢铁 是 怎样 炼成 的 插图 ...       小说            7
# 9      国外 电子 与 通信 教材 系列 数字通信 第 5 版 英文版 美 JOHNG . PROA...  大中专教材教辅            3
# 10     从 山峦 到 海洋 : 四十张 伟大 摄影 作品 的 创作 本书 集结 了 40 幅 作者 ...       艺术            8
# ...

# %%
import jieba

# %%
def query_cut(query):
    '''
    @description: word segment 分词
    @param {type} query: input data
    @return:
    list of cut word
    '''
    jieba.enable_parallel(4)
    return list(jieba.cut(query))

# %%
Stopwords = open('data/Stopwords.txt', 'r', encoding='utf-8').read().splitlines()

# %%
stopwords = open('data/stopwords.txt', 'r', encoding='utf-8').read().splitlines()

# %%
len(Stopwords), len(stopwords)
# Out:
# (13318, 13318)

# %%
stopwords
# Out:
# ['\ufeff¡',
#  '¦',
#  '«',
#  '\xad',
#  '¯',
#  '居于',
#  '以阿',
#  '请以',
#  '可别',
#  '得以',
#  '商与',
#  '说他',
#  '因为阿',
#  '就是阿',
#  '´',
#  '·',
#  '为您',
#  '出得',
#  '还有',
#  '就是',
#  '在产',
#  '也许就',
#  '¸',
#  '文中',
#  '在中',
#  '才有',
#  '而非',
#  '',
#  '就不能',
#  '为什么阿',
#  '是让',
#  '»',
#  '¿',
#  '×××',
#  '\\u3000',
#  '×',
#  '.h',
#  'tml',
#  '.h_tml',
#  '\\n',
#  '_',
#  '很多人',
#  '',
#  'ˇ',
#  'ˉ',
#  'ˊ',
#  '并与',
#  'ˋ',
#  '˜',
#  'Δ',
#  'Ψ',
#  'γ',
#  'μ',
#  'φ．',
#  'φ',
#  'В',
#  '‐',
#  '–',
#  '———',
#  '——',
#  '—\u3000',
#  '—',
#  '―',
#  '‖',
#  '‘',
#  '’‘',
#  '’',
#  '“',
#  '”，',
#  '”',
#  '•',
#  '………………………………………………',
#  '……………………………………………',
#  '……',
#  '…',
#  '′∈',
#  '′｜',
#  '′',
#  '‹',
#  '›',
#  '※',
#  '℃',
#  'Ⅲ',
#  '↑',
#  '→',
#  '∈［',
#  '∕',
#  '∥',
#  '∧',
#  '∪φ∈',
#  '≈',
#  '①',
#  '②ｃ',
#  '②',
#  '③］',
#  '③',
#  '④',
#  '⑤',
#  '⑥',
#  '⑦',
#  '⑧',
#  '⑨',
#  '·',
#  '⑩',
#  '──',
#  '─',
#  '│',
#  '■',
#  '▲',
#  '○',
#  '★',
# ...

# %%
def removeStopWords(query):
    return [word for word in query.split(" ") if word not in stopwords]

# %%
data["text"] = data["text"].apply(lambda x: " ".join(x))

# %%
sub_data = data.head()

# %%
sub_data['textRMStopwords'] = sub_data.text.apply(lambda x: [word for word in x.split(" ") if word not in stopwords])
# Out:
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sub_data.textRMStopwords
# Out:
# 0    [杏林, 芳菲, 广东, 中医药, 曹磊, 编著, 杏林, 芳菲, 广东, 中医药, 注重,...
# 1    [额吉, 白云, 优秀, 蒙古文, 文学作品, 翻译, 出版, 工程, 第五辑, 散文, 散...
# 2    [叶赛宁, 抒情诗, 收入, 叶赛宁, 206, 抒情诗, 多为, 名篇, 佳作, 叶赛宁,...
# 3    [长发, 走过, 唐诗, 路过, 宋词, 相约, 江南, 美文, 佳景, 长发, 臂弯, 寂...
# 4    [公司债务, 融资, 金融, 系统, 经济, 生活, 热点, 前沿, 公司债务, 融资, 多...
# Name: textRMStopwords, dtype: object

# %%
sub_data.textRMStopwords2 == sub_data.textRMStopwords
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
sub_data["textRMStopwords2"] = sub_data.text.apply(removeStopWords)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
